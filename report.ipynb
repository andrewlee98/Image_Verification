# %%
import pickle
import numpy as np
from os import listdir, path

# %%
x_train, y_train = pickle.load(open('train_data.pkl', 'rb'))
Xtrain = x_train.reshape(200, 500, 64, 64, 3)

# %%
from matplotlib import pyplot as plt

for i in range(5):
    plt.figure()
    plt.imshow(x_train[i].astype(np.uint8))
    plt.savefig(str(i) + '.png')
    plt.show()
    
for i in range(1000, 1005):
    plt.figure()
    plt.imshow(x_train[i].astype(np.uint8))
    plt.savefig(str(i) + '-2.png')
    plt.show()

# %%
 for label, folder in enumerate(listdir('tiny-imagenet-200/train')): print(folder)
# Out:
# n02669723
# n02486410
# n02206856
# n02999410
# n04074963
# n02883205
# n01768244
# n04099969
# n07768694
# n04366367
# n07579787
# n02841315
# n04070727
# n02892201
# n03706229
# n04560804
# n09193705
# n04597913
# n02165456
# n03970156
# n06596364
# n03447447
# n02423022
# n04487081
# n04376876
# n02124075
# n02909870
# n03042490
# n02099601
# n04008634
# n01882714
# n04507155
# n03160309
# n04275548
# n01855672
# n04532106
# n04254777
# n07875152
# n07711569
# n04465501
# n02481823
# n04146614
# n02988304
# n04417672
# n03179701
# n02364673
# n04501370
# n04562935
# n04133789
# n02190166
# n02236044
# n01774750
# n02769748
# n02129165
# n03250847
# n03089624
# n04179913
# n03400231
# n07720875
# n02837789
# n02437312
# n04328186
# n02268443
# n02099712
# n02231487
# n03026506
# n04251144
# n01774384
# n03201208
# n03930313
# n02504458
# n03980874
# n01983481
# n07734744
# n07873807
# n07615774
# n03388043
# n02948072
# n02788148
# n02123394
# n02815834
# n03976657
# n01698640
# ...
